# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
import pandas as pd
pd.set_option('display.max_rows', 1000)
import numpy as np
import string
import random
from SoundsLike.SoundsLike import Search
import Levenshtein

# %%
df = pd.read_csv("../../data/conll03/new_conll_train_preprocessed_without_punctuation.csv")
#df = pd.read_csv("../../data/conll03/new_conll_train_preprocessed_without_punctuation_with_broken_entities.csv")
#df = pd.read_csv("../../data/conll03/train.txt", sep=" ")
#df = pd.read_csv("data/dev.txt", sep=" ")
#df = pd.read_csv("data/test.txt", sep=" ")

# %%
df.head(100)
# Out:
#     Unnamed: 0  sentence_no            Word  Tag
# 0            0            0              EU  ORG
# 1            1            0         rejects    O
# 2            2            0          German    O
# 3            3            0            call    O
# 4            4            0              to    O
# 5            5            0         boycott    O
# 6            6            0         British    O
# 7            7            0            lamb    O
# 8            8            1           Peter  PER
# 9            9            1       Blackburn  PER
# 10          10            1        BRUSSELS  LOC
# 11          11            1        19960822    O
# 12          12            1             The    O
# 13          13            1        European  ORG
# 14          14            1      Commission  ORG
# 15          15            1            said    O
# 16          16            1              on    O
# 17          17            1        Thursday    O
# 18          18            1              it    O
# 19          19            1       disagreed    O
# 20          20            1            with    O
# 21          21            1          German    O
# 22          22            1          advice    O
# 23          23            1              to    O
# 24          24            1       consumers    O
# 25          25            1              to    O
# 26          26            1            shun    O
# 27          27            1         British    O
# 28          28            1            lamb    O
# 29          29            1           until    O
# 30          30            1      scientists    O
# 31          31            1       determine    O
# 32          32            1         whether    O
# 33          33            1             mad    O
# 34          34            1             cow    O
# 35          35            1         disease    O
# 36          36            1             can    O
# 37          37            1              be    O
# 38          38            1     transmitted    O
# 39          39            1              to    O
# 40          40            1           sheep    O
# 41          41            2        Germanys  LOC
# 42          42            2  representative    O
# 43          43            2              to    O
# 44          44            2             the    O
# 45          45            2        European  ORG
# 46          46            2          Unions  ORG
# 47          47            2      veterinary    O
# 48          48            2       committee    O
# 49          49            2          Werner  PER
# 50          50            2       Zwingmann  PER
# 51          51            2            said    O
# 52          52            2              on    O
# 53          53            2       Wednesday    O
# 54          54            2       consumers    O
# 55          55            2          should    O
# 56          56            2             buy    O
# 57          57            2       sheepmeat    O
# 58          58            2            from    O
# 59          59            2       countries    O
# 60          60            2           other    O
# 61          61            2            than    O
# 62          62            2         Britain  LOC
# 63          63            2           until    O
# 64          64            2             the    O
# 65          65            2      scientific    O
# 66          66            2          advice    O
# 67          67            2             was    O
# 68          68            2         clearer    O
# 69          69            3              We    O
# 70          70            3            dont    O
# 71          71            3         support    O
# 72          72            3             any    O
# 73          73            3            such    O
# 74          74            3  recommendation    O
# 75          75            3         because    O
# 76          76            3              we    O
# 77          77            3            dont    O
# 78          78            3             see    O
# 79          79            3             any    O
# 80          80            3         grounds    O
# 81          81            3             for    O
# 82          82            3              it    O
# 83          83            3             the    O
# 84          84            3     Commissions  ORG
# 85          85            3           chief    O
# 86          86            3       spokesman    O
# 87          87            3        Nikolaus  PER
# 88          88            3             van  PER
# 89          89            3             der  PER
# 90          90            3             Pas  PER
# 91          91            3            told    O
# 92          92            3               a    O
# 93          93            3            news    O
# 94          94            3        briefing    O
# 95          95            4              He    O
# 96          96            4            said    O
# 97          97            4         further    O
# 98          98            4      scientific    O
# 99          99            4           study    O

# %%
df = df[df['Tag'].notna()]

# %%
df.head()
# Out:
#    Unnamed: 0  sentence_no     Word  Tag
# 0           0            0       EU  ORG
# 1           1            0  rejects    O
# 2           2            0   German    O
# 3           3            0     call    O
# 4           4            0       to    O

# %%
df.drop(['Unnamed: 0'], axis=1, inplace=True)

# %%
df['Tag'].unique()
# Out:
# array(['ORG', 'O', 'PER', 'LOC'], dtype=object)

# %%
len(df)
# Out:
# 176949

# %%
df.dropna(axis=0, inplace=True)

# %%
df[df['Word'].isna()]
# Out:
# Empty DataFrame
# Columns: [sentence_no, Word, Tag]
# Index: []

# %%
df.head(100)
# Out:
#     sentence_no            Word  Tag
# 0             0              EU  ORG
# 1             0         rejects    O
# 2             0          German    O
# 3             0            call    O
# 4             0              to    O
# 5             0         boycott    O
# 6             0         British    O
# 7             0            lamb    O
# 8             1           Peter  PER
# 9             1       Blackburn  PER
# 10            1        BRUSSELS  LOC
# 11            1        19960822    O
# 12            1             The    O
# 13            1        European  ORG
# 14            1      Commission  ORG
# 15            1            said    O
# 16            1              on    O
# 17            1        Thursday    O
# 18            1              it    O
# 19            1       disagreed    O
# 20            1            with    O
# 21            1          German    O
# 22            1          advice    O
# 23            1              to    O
# 24            1       consumers    O
# 25            1              to    O
# 26            1            shun    O
# 27            1         British    O
# 28            1            lamb    O
# 29            1           until    O
# 30            1      scientists    O
# 31            1       determine    O
# 32            1         whether    O
# 33            1             mad    O
# 34            1             cow    O
# 35            1         disease    O
# 36            1             can    O
# 37            1              be    O
# 38            1     transmitted    O
# 39            1              to    O
# 40            1           sheep    O
# 41            2        Germanys  LOC
# 42            2  representative    O
# 43            2              to    O
# 44            2             the    O
# 45            2        European  ORG
# 46            2          Unions  ORG
# 47            2      veterinary    O
# 48            2       committee    O
# 49            2          Werner  PER
# 50            2       Zwingmann  PER
# 51            2            said    O
# 52            2              on    O
# 53            2       Wednesday    O
# 54            2       consumers    O
# 55            2          should    O
# 56            2             buy    O
# 57            2       sheepmeat    O
# 58            2            from    O
# 59            2       countries    O
# 60            2           other    O
# 61            2            than    O
# 62            2         Britain  LOC
# 63            2           until    O
# 64            2             the    O
# 65            2      scientific    O
# 66            2          advice    O
# 67            2             was    O
# 68            2         clearer    O
# 69            3              We    O
# 70            3            dont    O
# 71            3         support    O
# 72            3             any    O
# 73            3            such    O
# 74            3  recommendation    O
# 75            3         because    O
# 76            3              we    O
# 77            3            dont    O
# 78            3             see    O
# 79            3             any    O
# 80            3         grounds    O
# 81            3             for    O
# 82            3              it    O
# 83            3             the    O
# 84            3     Commissions  ORG
# 85            3           chief    O
# 86            3       spokesman    O
# 87            3        Nikolaus  PER
# 88            3             van  PER
# 89            3             der  PER
# 90            3             Pas  PER
# 91            3            told    O
# 92            3               a    O
# 93            3            news    O
# 94            3        briefing    O
# 95            4              He    O
# 96            4            said    O
# 97            4         further    O
# 98            4      scientific    O
# 99            4           study    O

# %%
dataset = []
for sentence_no, tag, word in zip(df['sentence_no'].values.tolist(), df['Tag'].values.tolist(), df['Word'].values.tolist()):
    if tag != "O":
        error = []
        try:
            x = Search.perfectHomophones(word)
            for d in x:
                err = Levenshtein.distance(word, d)
                error.append(err)
                word = x[error.index(max(error))]
        except ValueError:
            pass 
        dataset.append((sentence_no, tag, word))
    else:
        dataset.append((sentence_no, tag, word))
df = pd.DataFrame(dataset, columns=['Sentence #', 'Tag', 'Word'])

# %%
df.head(100)
# Out:
#     Sentence #  Tag            Word
# 0            0  ORG              Eu
# 1            0    O         rejects
# 2            0    O          German
# 3            0    O            call
# 4            0    O              to
# 5            0    O         boycott
# 6            0    O         British
# 7            0    O            lamb
# 8            1  PER          Pieter
# 9            1  PER       Blackburn
# 10           1  LOC        Brussels
# 11           1    O        19960822
# 12           1    O             The
# 13           1  ORG        European
# 14           1  ORG       Commision
# 15           1    O            said
# 16           1    O              on
# 17           1    O        Thursday
# 18           1    O              it
# 19           1    O       disagreed
# 20           1    O            with
# 21           1    O          German
# 22           1    O          advice
# 23           1    O              to
# 24           1    O       consumers
# 25           1    O              to
# 26           1    O            shun
# 27           1    O         British
# 28           1    O            lamb
# 29           1    O           until
# 30           1    O      scientists
# 31           1    O       determine
# 32           1    O         whether
# 33           1    O             mad
# 34           1    O             cow
# 35           1    O         disease
# 36           1    O             can
# 37           1    O              be
# 38           1    O     transmitted
# 39           1    O              to
# 40           1    O           sheep
# 41           2  LOC       Germany'S
# 42           2    O  representative
# 43           2    O              to
# 44           2    O             the
# 45           2  ORG        European
# 46           2  ORG         Union'S
# 47           2    O      veterinary
# 48           2    O       committee
# 49           2  PER          Werner
# 50           2  PER       Zwingmann
# 51           2    O            said
# 52           2    O              on
# 53           2    O       Wednesday
# 54           2    O       consumers
# 55           2    O          should
# 56           2    O             buy
# 57           2    O       sheepmeat
# 58           2    O            from
# 59           2    O       countries
# 60           2    O           other
# 61           2    O            than
# 62           2  LOC        Brittain
# 63           2    O           until
# 64           2    O             the
# 65           2    O      scientific
# 66           2    O          advice
# 67           2    O             was
# 68           2    O         clearer
# 69           3    O              We
# 70           3    O            dont
# 71           3    O         support
# 72           3    O             any
# 73           3    O            such
# 74           3    O  recommendation
# 75           3    O         because
# 76           3    O              we
# 77           3    O            dont
# 78           3    O             see
# 79           3    O             any
# 80           3    O         grounds
# 81           3    O             for
# 82           3    O              it
# 83           3    O             the
# 84           3  ORG    Commission'S
# 85           3    O           chief
# 86           3    O       spokesman
# 87           3  PER        Nicolaus
# 88           3  PER             Van
# 89           3  PER            Dirr
# 90           3  PER             Paz
# 91           3    O            told
# 92           3    O               a
# 93           3    O            news
# 94           3    O        briefing
# 95           4    O              He
# 96           4    O            said
# 97           4    O         further
# 98           4    O      scientific
# 99           4    O           study

# %%
old_df = df

# %%
entities = df[df['Tag'] != "O"]['Sentence #'].values.tolist()

# %%
per_entities = df[df['Tag'] == "PER"]['Sentence #'].values.tolist()

# %%
per_entities
# Out:
# [1,
#  1,
#  2,
#  2,
#  3,
#  3,
#  3,
#  3,
#  5,
#  5,
#  6,
#  7,
#  8,
#  8,
#  8,
#  8,
#  9,
#  13,
#  13,
#  13,
#  17,
#  18,
#  18,
#  19,
#  21,
#  21,
#  21,
#  22,
#  25,
#  25,
#  26,
#  26,
#  27,
#  27,
#  28,
#  29,
#  30,
#  33,
#  33,
#  48,
#  48,
#  48,
#  48,
#  49,
#  49,
#  49,
#  50,
#  50,
#  51,
#  51,
#  57,
#  57,
#  58,
#  58,
#  61,
#  62,
#  62,
#  67,
#  67,
#  67,
#  67,
#  67,
#  68,
#  68,
#  72,
#  74,
#  78,
#  78,
#  79,
#  83,
#  83,
#  84,
#  87,
#  87,
#  88,
#  88,
#  88,
#  88,
#  106,
#  107,
#  107,
#  107,
#  109,
#  109,
#  109,
#  110,
#  110,
#  110,
#  111,
#  111,
#  111,
#  112,
#  113,
#  113,
#  113,
#  114,
#  114,
#  115,
#  115,
#  115,
#  115,
#  116,
#  116,
#  116,
#  117,
#  117,
#  118,
#  118,
#  118,
#  120,
#  120,
#  130,
#  130,
#  134,
#  138,
#  138,
#  139,
#  139,
#  139,
#  139,
#  140,
#  140,
#  141,
#  141,
#  142,
#  144,
#  145,
#  149,
#  149,
#  149,
#  149,
#  156,
#  157,
#  161,
#  162,
#  174,
#  174,
#  176,
#  176,
#  180,
#  180,
#  182,
#  182,
#  182,
#  182,
#  183,
#  183,
#  183,
#  184,
#  184,
#  186,
#  186,
#  206,
#  206,
#  211,
#  211,
#  221,
#  221,
#  221,
#  221,
#  221,
#  221,
#  221,
#  221,
#  221,
#  221,
#  221,
#  221,
#  221,
#  221,
#  221,
#  221,
#  221,
#  221,
#  221,
#  221,
#  221,
#  221,
#  221,
#  221,
#  221,
#  221,
#  221,
#  221,
#  221,
#  221,
#  221,
#  221,
#  221,
#  221,
#  221,
#  221,
#  221,
#  221,
#  221,
#  221,
#  221,
#  221,
#  221,
#  221,
#  221,
#  221,
#  221,
#  221,
#  221,
#  221,
#  221,
#  221,
#  221,
#  221,
#  221,
#  221,
#  221,
#  221,
#  221,
#  221,
#  221,
#  221,
#  221,
#  221,
#  221,
#  221,
#  221,
#  221,
#  221,
#  221,
#  221,
#  221,
#  221,
#  221,
#  221,
#  221,
#  221,
#  221,
#  221,
#  221,
#  221,
#  221,
#  221,
#  221,
#  221,
#  221,
#  223,
#  223,
#  223,
#  223,
#  223,
#  223,
#  224,
#  224,
#  224,
#  225,
#  225,
#  225,
#  226,
#  226,
#  226,
#  226,
#  226,
#  226,
#  226,
#  227,
#  227,
#  227,
#  227,
#  227,
#  228,
#  228,
#  228,
#  229,
#  230,
#  230,
#  231,
#  231,
#  231,
#  231,
#  231,
#  232,
#  233,
#  233,
#  235,
#  235,
#  235,
#  235,
#  235,
#  235,
#  235,
#  235,
#  235,
#  235,
#  235,
#  236,
#  236,
#  237,
#  237,
#  239,
#  239,
#  239,
#  239,
#  239,
#  239,
#  239,
#  239,
#  239,
#  239,
#  239,
#  239,
#  239,
#  239,
#  239,
#  239,
#  239,
#  240,
#  240,
#  240,
#  240,
#  240,
#  240,
#  240,
#  240,
#  240,
#  240,
#  240,
#  240,
#  240,
#  240,
#  240,
#  240,
#  240,
#  240,
#  241,
#  241,
#  242,
#  244,
#  248,
#  250,
#  250,
#  250,
#  250,
#  250,
#  250,
#  251,
#  251,
#  252,
#  252,
#  252,
#  252,
#  252,
#  252,
#  254,
#  254,
#  254,
#  254,
#  255,
#  255,
#  255,
#  255,
#  256,
#  256,
#  256,
#  256,
#  256,
#  256,
#  257,
#  257,
#  257,
#  257,
#  258,
#  258,
#  258,
#  258,
#  259,
#  259,
#  259,
#  259,
#  259,
#  259,
#  261,
#  261,
#  261,
#  261,
#  261,
#  261,
#  261,
#  261,
#  261,
#  261,
#  261,
#  261,
#  261,
#  261,
#  261,
#  261,
#  261,
#  261,
#  261,
#  261,
#  261,
#  261,
#  261,
#  261,
#  261,
#  261,
#  261,
#  261,
#  261,
#  261,
#  261,
#  261,
#  261,
#  261,
#  261,
#  261,
#  261,
#  261,
#  261,
#  261,
#  261,
#  261,
#  261,
#  261,
#  261,
#  261,
#  261,
#  261,
#  261,
#  261,
#  261,
#  261,
#  261,
#  261,
#  261,
#  261,
#  261,
#  261,
#  261,
#  261,
#  261,
#  261,
#  261,
#  261,
#  261,
#  261,
#  261,
#  261,
#  262,
#  262,
#  263,
#  263,
#  264,
#  265,
#  265,
#  265,
#  265,
#  266,
#  266,
#  267,
#  267,
#  270,
#  271,
#  271,
#  272,
#  272,
#  272,
#  274,
#  274,
#  274,
#  274,
#  274,
#  274,
#  274,
#  274,
#  274,
#  274,
#  274,
#  274,
#  274,
#  274,
#  274,
#  274,
#  274,
#  274,
#  274,
#  274,
#  274,
#  274,
#  274,
#  274,
#  274,
#  274,
#  274,
#  274,
#  274,
#  274,
#  274,
#  274,
#  274,
#  274,
#  274,
#  274,
#  274,
#  274,
#  274,
#  274,
#  274,
#  274,
#  274,
#  274,
#  274,
#  274,
#  274,
#  274,
#  274,
#  274,
#  274,
#  274,
#  274,
#  274,
#  274,
#  274,
#  274,
#  274,
#  274,
#  274,
#  274,
#  275,
#  275,
#  276,
#  276,
#  278,
#  278,
#  278,
#  278,
#  278,
#  278,
#  278,
#  278,
#  279,
#  279,
#  279,
#  279,
#  279,
#  279,
#  279,
#  279,
#  279,
#  279,
#  279,
#  279,
#  279,
#  279,
#  279,
#  279,
#  282,
#  282,
#  282,
#  282,
#  282,
#  282,
#  282,
#  282,
#  282,
#  282,
#  284,
#  284,
#  284,
#  284,
#  286,
#  286,
#  286,
#  286,
#  286,
#  286,
#  288,
#  288,
#  288,
#  288,
#  288,
#  288,
#  288,
#  288,
#  288,
#  288,
#  289,
#  289,
#  295,
#  295,
#  295,
#  295,
#  295,
#  295,
#  296,
#  296,
#  296,
#  296,
#  301,
#  301,
#  301,
#  301,
#  303,
#  304,
#  304,
#  305,
#  305,
#  306,
#  306,
#  308,
#  309,
#  309,
#  309,
#  309,
#  310,
#  310,
#  310,
#  310,
#  310,
#  310,
#  310,
#  310,
#  310,
#  310,
#  310,
#  311,
#  311,
#  311,
#  312,
#  313,
#  315,
#  315,
#  315,
#  315,
#  315,
#  315,
#  315,
#  315,
#  315,
#  315,
#  315,
#  315,
#  315,
#  315,
#  315,
#  315,
#  315,
#  315,
#  315,
#  315,
#  315,
#  315,
#  315,
#  315,
#  315,
#  315,
#  315,
#  315,
#  315,
#  315,
#  315,
#  315,
#  315,
#  315,
#  315,
#  315,
#  315,
#  315,
#  315,
#  315,
#  315,
#  315,
#  315,
#  315,
#  315,
#  315,
#  315,
#  315,
#  315,
#  315,
#  315,
#  315,
#  315,
#  315,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  318,
#  318,
#  319,
#  320,
#  320,
#  320,
#  321,
#  321,
#  321,
#  322,
#  322,
#  322,
#  323,
#  323,
#  323,
#  328,
#  329,
#  329,
#  330,
#  330,
#  330,
#  331,
#  334,
#  334,
#  335,
#  335,
#  335,
#  335,
#  335,
#  335,
#  339,
#  339,
#  340,
#  340,
#  341,
#  341,
#  342,
#  342,
#  342,
#  342,
#  343,
#  343,
#  343,
#  344,
#  344,
#  344,
#  344,
#  344,
#  345,
#  347,
#  347,
#  348,
#  348,
#  349,
#  350,
#  350,
#  351,
#  351,
#  351,
#  351,
#  352,
#  352,
#  352,
#  354,
#  354,
#  356,
#  356,
#  357,
#  357,
#  358,
#  359,
#  359,
#  360,
#  360,
#  361,
#  361,
#  364,
#  364,
#  365,
#  367,
#  367,
#  368,
#  369,
#  369,
#  370,
#  371,
#  371,
#  373,
#  373,
#  373,
#  373,
#  376,
#  ...]

# %%
per_randomlist = random.sample(per_entities, int(len(per_entities)/2))
per_randomlist.sort()

# %%
len(per_randomlist)
# Out:
# 11124

# %%
for ind, sentence_no, tag, word in zip(df.index.tolist(), df['Sentence #'].values.tolist(), df['Tag'].values.tolist(), df['Word'].values.tolist()):
    if sentence_no in per_entities and tag == "PER":
        row1, row3 = df.iloc[ind-1].copy(), df.iloc[ind+1].copy()
        df.iloc[ind-1], df.iloc[ind+1] = row3, row1

# %%
df.head(100)
# Out:
#     Sentence #  Tag            Word
# 0            0  ORG              Eu
# 1            0    O         rejects
# 2            0    O          German
# 3            0    O            call
# 4            0    O              to
# 5            0    O         boycott
# 6            0    O         British
# 7            1  PER       Blackburn
# 8            1  LOC        Brussels
# 9            0    O            lamb
# 10           1  PER          Pieter
# 11           1    O        19960822
# 12           1    O             The
# 13           1  ORG        European
# 14           1  ORG       Commision
# 15           1    O            said
# 16           1    O              on
# 17           1    O        Thursday
# 18           1    O              it
# 19           1    O       disagreed
# 20           1    O            with
# 21           1    O          German
# 22           1    O          advice
# 23           1    O              to
# 24           1    O       consumers
# 25           1    O              to
# 26           1    O            shun
# 27           1    O         British
# 28           1    O            lamb
# 29           1    O           until
# 30           1    O      scientists
# 31           1    O       determine
# 32           1    O         whether
# 33           1    O             mad
# 34           1    O             cow
# 35           1    O         disease
# 36           1    O             can
# 37           1    O              be
# 38           1    O     transmitted
# 39           1    O              to
# 40           1    O           sheep
# 41           2  LOC       Germany'S
# 42           2    O  representative
# 43           2    O              to
# 44           2    O             the
# 45           2  ORG        European
# 46           2  ORG         Union'S
# 47           2    O      veterinary
# 48           2  PER       Zwingmann
# 49           2    O            said
# 50           2    O       committee
# 51           2  PER          Werner
# 52           2    O              on
# 53           2    O       Wednesday
# 54           2    O       consumers
# 55           2    O          should
# 56           2    O             buy
# 57           2    O       sheepmeat
# 58           2    O            from
# 59           2    O       countries
# 60           2    O           other
# 61           2    O            than
# 62           2  LOC        Brittain
# 63           2    O           until
# 64           2    O             the
# 65           2    O      scientific
# 66           2    O          advice
# 67           2    O             was
# 68           2    O         clearer
# 69           3    O              We
# 70           3    O            dont
# 71           3    O         support
# 72           3    O             any
# 73           3    O            such
# 74           3    O  recommendation
# 75           3    O         because
# 76           3    O              we
# 77           3    O            dont
# 78           3    O             see
# 79           3    O             any
# 80           3    O         grounds
# 81           3    O             for
# 82           3    O              it
# 83           3    O             the
# 84           3  ORG    Commission'S
# 85           3    O           chief
# 86           3  PER             Van
# 87           3  PER            Dirr
# 88           3  PER             Paz
# 89           3    O            told
# 90           3    O       spokesman
# 91           3  PER        Nicolaus
# 92           3    O               a
# 93           3    O            news
# 94           3    O        briefing
# 95           4    O              He
# 96           4    O            said
# 97           4    O         further
# 98           4    O      scientific
# 99           4    O           study

# %%
loc_entities = df[df['Tag'] == "LOC"]['Sentence #'].values.tolist()

# %%
loc_entities
# Out:
# [1,
#  2,
#  2,
#  6,
#  6,
#  9,
#  9,
#  12,
#  13,
#  14,
#  15,
#  15,
#  18,
#  18,
#  19,
#  19,
#  20,
#  24,
#  24,
#  25,
#  25,
#  25,
#  25,
#  25,
#  25,
#  25,
#  26,
#  26,
#  27,
#  27,
#  27,
#  29,
#  29,
#  30,
#  30,
#  30,
#  31,
#  31,
#  32,
#  32,
#  32,
#  35,
#  48,
#  51,
#  52,
#  52,
#  52,
#  53,
#  54,
#  54,
#  54,
#  54,
#  54,
#  54,
#  54,
#  55,
#  55,
#  55,
#  56,
#  57,
#  56,
#  57,
#  57,
#  58,
#  58,
#  58,
#  58,
#  60,
#  62,
#  63,
#  63,
#  63,
#  64,
#  65,
#  65,
#  65,
#  67,
#  68,
#  68,
#  68,
#  68,
#  68,
#  68,
#  69,
#  69,
#  71,
#  73,
#  73,
#  76,
#  76,
#  76,
#  79,
#  79,
#  79,
#  79,
#  79,
#  80,
#  81,
#  81,
#  83,
#  83,
#  84,
#  84,
#  85,
#  87,
#  86,
#  87,
#  87,
#  87,
#  88,
#  88,
#  89,
#  89,
#  91,
#  91,
#  91,
#  92,
#  93,
#  93,
#  93,
#  95,
#  95,
#  97,
#  97,
#  97,
#  98,
#  98,
#  100,
#  106,
#  106,
#  106,
#  107,
#  107,
#  107,
#  107,
#  109,
#  109,
#  110,
#  110,
#  110,
#  110,
#  110,
#  111,
#  112,
#  112,
#  112,
#  112,
#  112,
#  113,
#  113,
#  113,
#  113,
#  114,
#  115,
#  115,
#  115,
#  115,
#  116,
#  116,
#  116,
#  117,
#  117,
#  117,
#  119,
#  120,
#  120,
#  120,
#  120,
#  120,
#  120,
#  120,
#  121,
#  122,
#  125,
#  125,
#  125,
#  125,
#  126,
#  128,
#  128,
#  128,
#  129,
#  130,
#  131,
#  131,
#  133,
#  134,
#  135,
#  137,
#  137,
#  137,
#  138,
#  139,
#  138,
#  139,
#  139,
#  140,
#  140,
#  141,
#  141,
#  141,
#  142,
#  142,
#  142,
#  143,
#  143,
#  143,
#  144,
#  145,
#  146,
#  147,
#  149,
#  150,
#  150,
#  151,
#  151,
#  151,
#  151,
#  152,
#  153,
#  153,
#  157,
#  157,
#  157,
#  158,
#  159,
#  159,
#  160,
#  160,
#  164,
#  170,
#  170,
#  181,
#  182,
#  184,
#  185,
#  186,
#  190,
#  191,
#  191,
#  192,
#  194,
#  195,
#  195,
#  199,
#  201,
#  204,
#  205,
#  205,
#  209,
#  209,
#  211,
#  211,
#  216,
#  216,
#  219,
#  221,
#  221,
#  221,
#  221,
#  221,
#  221,
#  221,
#  221,
#  221,
#  221,
#  221,
#  221,
#  221,
#  221,
#  221,
#  221,
#  221,
#  221,
#  221,
#  221,
#  221,
#  222,
#  222,
#  222,
#  225,
#  225,
#  227,
#  228,
#  235,
#  235,
#  237,
#  239,
#  239,
#  239,
#  239,
#  239,
#  239,
#  239,
#  239,
#  239,
#  239,
#  240,
#  240,
#  240,
#  240,
#  240,
#  240,
#  240,
#  240,
#  240,
#  240,
#  240,
#  240,
#  241,
#  244,
#  250,
#  250,
#  252,
#  254,
#  255,
#  256,
#  257,
#  257,
#  258,
#  259,
#  260,
#  260,
#  261,
#  261,
#  261,
#  261,
#  261,
#  261,
#  261,
#  262,
#  263,
#  263,
#  264,
#  265,
#  268,
#  269,
#  269,
#  269,
#  269,
#  269,
#  270,
#  270,
#  271,
#  271,
#  274,
#  274,
#  274,
#  274,
#  274,
#  274,
#  274,
#  274,
#  274,
#  274,
#  274,
#  274,
#  274,
#  274,
#  274,
#  274,
#  274,
#  274,
#  274,
#  274,
#  274,
#  274,
#  274,
#  274,
#  274,
#  274,
#  274,
#  274,
#  274,
#  274,
#  274,
#  274,
#  274,
#  274,
#  274,
#  274,
#  275,
#  275,
#  276,
#  276,
#  276,
#  278,
#  278,
#  278,
#  278,
#  278,
#  278,
#  278,
#  278,
#  278,
#  279,
#  279,
#  279,
#  279,
#  279,
#  279,
#  279,
#  279,
#  279,
#  280,
#  280,
#  280,
#  282,
#  282,
#  282,
#  282,
#  282,
#  282,
#  284,
#  284,
#  284,
#  284,
#  284,
#  285,
#  286,
#  286,
#  286,
#  287,
#  287,
#  287,
#  287,
#  288,
#  288,
#  288,
#  288,
#  288,
#  289,
#  289,
#  289,
#  291,
#  291,
#  291,
#  293,
#  293,
#  294,
#  294,
#  294,
#  298,
#  299,
#  299,
#  299,
#  300,
#  302,
#  302,
#  302,
#  304,
#  304,
#  305,
#  305,
#  306,
#  307,
#  307,
#  308,
#  312,
#  313,
#  313,
#  315,
#  315,
#  315,
#  315,
#  315,
#  315,
#  315,
#  315,
#  315,
#  315,
#  315,
#  315,
#  315,
#  315,
#  315,
#  315,
#  315,
#  315,
#  315,
#  315,
#  315,
#  315,
#  315,
#  315,
#  315,
#  315,
#  315,
#  315,
#  315,
#  315,
#  315,
#  315,
#  316,
#  316,
#  316,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  317,
#  318,
#  322,
#  322,
#  322,
#  322,
#  322,
#  323,
#  327,
#  327,
#  327,
#  327,
#  327,
#  327,
#  327,
#  327,
#  327,
#  327,
#  327,
#  327,
#  327,
#  327,
#  327,
#  327,
#  327,
#  328,
#  328,
#  329,
#  337,
#  337,
#  342,
#  346,
#  350,
#  351,
#  351,
#  356,
#  356,
#  356,
#  357,
#  359,
#  361,
#  364,
#  364,
#  367,
#  371,
#  376,
#  379,
#  380,
#  380,
#  380,
#  380,
#  383,
#  386,
#  386,
#  389,
#  389,
#  395,
#  395,
#  395,
#  395,
#  395,
#  395,
#  395,
#  395,
#  395,
#  395,
#  395,
#  395,
#  395,
#  395,
#  395,
#  395,
#  395,
#  395,
#  395,
#  395,
#  395,
#  395,
#  395,
#  395,
#  395,
#  395,
#  395,
#  395,
#  395,
#  396,
#  396,
#  396,
#  396,
#  397,
#  397,
#  397,
#  401,
#  401,
#  401,
#  401,
#  401,
#  401,
#  401,
#  401,
#  401,
#  401,
#  401,
#  401,
#  401,
#  401,
#  401,
#  401,
#  401,
#  401,
#  401,
#  401,
#  401,
#  401,
#  401,
#  401,
#  401,
#  401,
#  401,
#  401,
#  401,
#  401,
#  401,
#  401,
#  401,
#  401,
#  401,
#  401,
#  401,
#  401,
#  401,
#  401,
#  401,
#  401,
#  401,
#  401,
#  401,
#  401,
#  401,
#  401,
#  402,
#  402,
#  402,
#  402,
#  403,
#  403,
#  403,
#  403,
#  403,
#  405,
#  410,
#  411,
#  411,
#  412,
#  412,
#  412,
#  418,
#  418,
#  419,
#  424,
#  429,
#  429,
#  432,
#  432,
#  449,
#  451,
#  451,
#  451,
#  451,
#  451,
#  451,
#  451,
#  451,
#  451,
#  460,
#  460,
#  462,
#  463,
#  464,
#  470,
#  478,
#  481,
#  481,
#  482,
#  482,
#  482,
#  482,
#  484,
#  485,
#  485,
#  489,
#  489,
#  490,
#  490,
#  490,
#  493,
#  493,
#  493,
#  494,
#  497,
#  501,
#  508,
#  510,
#  510,
#  510,
#  512,
#  512,
#  513,
#  513,
#  513,
#  513,
#  513,
#  514,
#  514,
#  517,
#  517,
#  527,
#  529,
#  529,
#  529,
#  538,
#  539,
#  540,
#  540,
#  540,
#  542,
#  543,
#  544,
#  544,
#  545,
#  546,
#  549,
#  551,
#  553,
#  554,
#  555,
#  555,
#  556,
#  558,
#  558,
#  558,
#  559,
#  559,
#  564,
#  565,
#  566,
#  566,
#  566,
#  566,
#  568,
#  568,
#  568,
#  568,
#  570,
#  571,
#  571,
#  574,
#  575,
#  576,
#  578,
#  579,
#  579,
#  579,
#  580,
#  580,
#  580,
#  582,
#  585,
#  587,
#  587,
#  588,
#  588,
#  589,
#  593,
#  595,
#  596,
#  596,
#  596,
#  597,
#  598,
#  600,
#  600,
#  600,
#  600,
#  601,
#  602,
#  604,
#  606,
#  606,
#  607,
#  608,
#  608,
#  612,
#  613,
#  613,
#  613,
#  614,
#  614,
#  614,
#  615,
#  616,
#  617,
#  617,
#  617,
#  618,
#  618,
#  620,
#  622,
#  622,
#  622,
#  622,
#  623,
#  623,
#  623,
#  623,
#  626,
#  628,
#  628,
#  632,
#  633,
#  633,
#  634,
#  634,
#  634,
#  638,
#  639,
#  640,
#  640,
#  641,
#  641,
#  641,
#  648,
#  648,
#  652,
#  652,
#  652,
#  652,
#  660,
#  660,
#  661,
#  661,
#  662,
#  662,
#  662,
#  663,
#  663,
#  663,
#  664,
#  664,
#  664,
#  664,
#  664,
#  665,
#  665,
#  665,
#  665,
#  665,
#  666,
#  666,
#  668,
#  668,
#  668,
#  668,
#  668,
#  670,
#  670,
#  671,
#  671,
#  671,
#  671,
#  672,
#  673,
#  673,
#  673,
#  682,
#  682,
#  682,
#  682,
#  683,
#  683,
#  684,
#  ...]

# %%
loc_randomlist = random.sample(loc_entities, int(len(loc_entities)/2))
loc_randomlist.sort()

# %%
for ind, sentence_no, tag, word in zip(df.index.tolist(), df['Sentence #'].values.tolist(), df['Tag'].values.tolist(), df['Word'].values.tolist()):
    if sentence_no in loc_entities and tag == "LOC":
        row1, row3 = df.iloc[ind-1].copy(), df.iloc[ind+1].copy()
        df.iloc[ind-1], df.iloc[ind+1] = row3, row1

# %%
org_entities = df[df['Tag'] == "ORG"]['Sentence #'].values.tolist()

# %%
org_randomlist = random.sample(org_entities, int(len(org_entities)/2))
org_randomlist.sort()

# %%
for ind, sentence_no, tag, word in zip(df.index.tolist(), df['Sentence #'].values.tolist(), df['Tag'].values.tolist(), df['Word'].values.tolist()):
    if sentence_no in org_entities and tag == "ORG":
        row1, row3 = df.iloc[ind-1].copy(), df.iloc[ind+1].copy()
        df.iloc[ind-1], df.iloc[ind+1] = row3, row1

# %%
df.head(100)
# Out:
#     Sentence #  Tag            Word
# 0            0  ORG              Eu
# 1         7371    O               2
# 2            0    O          German
# 3            0    O            call
# 4            0    O              to
# 5            0    O         boycott
# 6            0    O         British
# 7            0    O            lamb
# 8            1  LOC        Brussels
# 9            1  PER       Blackburn
# 10           1  PER          Pieter
# 11           1    O        19960822
# 12           1  ORG       Commision
# 13           1    O            said
# 14           1    O             The
# 15           1  ORG        European
# 16           1    O              on
# 17           1    O        Thursday
# 18           1    O              it
# 19           1    O       disagreed
# 20           1    O            with
# 21           1    O          German
# 22           1    O          advice
# 23           1    O              to
# 24           1    O       consumers
# 25           1    O              to
# 26           1    O            shun
# 27           1    O         British
# 28           1    O            lamb
# 29           1    O           until
# 30           1    O      scientists
# 31           1    O       determine
# 32           1    O         whether
# 33           1    O             mad
# 34           1    O             cow
# 35           1    O         disease
# 36           1    O             can
# 37           1    O              be
# 38           1    O     transmitted
# 39           1    O              to
# 40           2    O  representative
# 41           2  LOC       Germany'S
# 42           1    O           sheep
# 43           2    O              to
# 44           2  ORG         Union'S
# 45           2    O      veterinary
# 46           2    O             the
# 47           2  ORG        European
# 48           2  PER       Zwingmann
# 49           2    O            said
# 50           2    O       committee
# 51           2  PER          Werner
# 52           2    O              on
# 53           2    O       Wednesday
# 54           2    O       consumers
# 55           2    O          should
# 56           2    O             buy
# 57           2    O       sheepmeat
# 58           2    O            from
# 59           2    O       countries
# 60           2    O           other
# 61           2    O           until
# 62           2  LOC        Brittain
# 63           2    O            than
# 64           2    O             the
# 65           2    O      scientific
# 66           2    O          advice
# 67           2    O             was
# 68           2    O         clearer
# 69           3    O              We
# 70           3    O            dont
# 71           3    O         support
# 72           3    O             any
# 73           3    O            such
# 74           3    O  recommendation
# 75           3    O         because
# 76           3    O              we
# 77           3    O            dont
# 78           3    O             see
# 79           3    O             any
# 80           3    O         grounds
# 81           3    O             for
# 82           3    O              it
# 83           3    O           chief
# 84           3  ORG    Commission'S
# 85           3    O             the
# 86           3  PER             Van
# 87           3  PER            Dirr
# 88           3  PER             Paz
# 89           3    O            told
# 90           3    O       spokesman
# 91           3  PER        Nicolaus
# 92           3    O               a
# 93           3    O            news
# 94           3    O        briefing
# 95           4    O              He
# 96           4    O            said
# 97           4    O         further
# 98           4    O      scientific
# 99           4    O           study

# %%
new_df = df.copy()

# %%
new_df.head()
# Out:
#    Sentence #  Tag    Word
# 0           0  ORG      Eu
# 1        7371    O       2
# 2           0    O  German
# 3           0    O    call
# 4           0    O      to

# %%
new_df.drop('Sentence #', axis=1, inplace=True)

# %%
new_df.head()
# Out:
#    Tag    Word
# 0  ORG      Eu
# 1    O       2
# 2    O  German
# 3    O    call
# 4    O      to

# %%
new_df['Sentence #'] = df['sentence_no']

# %%
new_df.tail()
# Out:
#         Tag     Word  Sentence #
# 176941    O        1      7371.0
# 176942  ORG  Swansea      7371.0
# 176943    O  rejects      7371.0
# 176944  ORG  Lincoln      7371.0
# 176945    O    three      7371.0

# %%
new_df.to_csv("../../data/conll03/new_conll_train_preprocessed_without_punctuation_with_broken_entities_broken_context1.csv")
